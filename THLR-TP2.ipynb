# %%
import vcsn
b = vcsn.context("lal_char(abc), b")
b
# Out:
# {abc} -> B

# %%
e1 = b.expression("ab*")
e1
# Out:
# ab*

# %%
e2 = b.expression("ab{+}")
e2
# Out:
# abb*

# %%
e3 = b.expression("ab* + ab{+}")
e3
# Out:
# ab*+abb*

# %%
e4 = b.expression("abc + (bac)* + (cab){+}")
e4
# Out:
# abc+(bac)*+cab(cab)*

# %%
e5 = b.expression("[a-c]*[^a]")
e5
# Out:
# (a+b+c)*(b+c)

# %%
e6 = b.expression("a?bc + ab?c")
e6
# Out:
# a(\e+b)c+(\e+a)bc

# %%
a1 = e1.thompson()
a1
# Out:
# mutable_automaton<context<nullableset<letterset<char_letters>>, b>>

# %%
a2 = e2.thompson()
a2
# Out:
# mutable_automaton<context<nullableset<letterset<char_letters>>, b>>

# %%
a3 = e3.thompson()
a3
# Out:
# mutable_automaton<context<nullableset<letterset<char_letters>>, b>>

# %%
a4 = e4.thompson()
a4
# Out:
# mutable_automaton<context<nullableset<letterset<char_letters>>, b>>

# %%
a5 = e5.thompson()
a5
# Out:
# mutable_automaton<context<nullableset<letterset<char_letters>>, b>>

# %%
a6 = e6.thompson()
a6
# Out:
# mutable_automaton<context<nullableset<letterset<char_letters>>, b>>

# %%
a1 = a1.proper(direction="backward", prune=True)
a1
# Out:
# mutable_automaton<context<letterset<char_letters>, b>>

# %%
a2 = a2.proper(direction="backward", prune=True)
a2
# Out:
# mutable_automaton<context<letterset<char_letters>, b>>

# %%
a3 = a3.proper(direction="backward", prune=True)
a3
# Out:
# mutable_automaton<context<letterset<char_letters>, b>>

# %%
a4 = a4.proper(direction="backward", prune=True)
a4
# Out:
# mutable_automaton<context<letterset<char_letters>, b>>

# %%
a5 = a5.proper(direction="backward", prune=True)
a5
# Out:
# mutable_automaton<context<letterset<char_letters>, b>>

# %%
a6 = a6.proper(direction="backward", prune=True)
a6
# Out:
# mutable_automaton<context<letterset<char_letters>, b>>

# %%
a1 = a1.trim()
a1
# Out:
# filter_automaton<mutable_automaton<context<letterset<char_letters>, b>>>

# %%
a2 = a2.trim()
a2
# Out:
# filter_automaton<mutable_automaton<context<letterset<char_letters>, b>>>

# %%
a3 = a3.trim()
a3
# Out:
# filter_automaton<mutable_automaton<context<letterset<char_letters>, b>>>

# %%
a4 = a4.trim()
a4
# Out:
# filter_automaton<mutable_automaton<context<letterset<char_letters>, b>>>

# %%
a5 = a5.trim()
a5
# Out:
# filter_automaton<mutable_automaton<context<letterset<char_letters>, b>>>

# %%
a6 = a6.trim()
a6
# Out:
# filter_automaton<mutable_automaton<context<letterset<char_letters>, b>>>
